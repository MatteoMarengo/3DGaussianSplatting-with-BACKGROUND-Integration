# %%
import os
from PIL import Image
import torch

# %%
bg_color = [1, 1, 0]
background = torch.tensor(bg_color, dtype=torch.float32, device="cuda")
print(background.shape)
# Out:
# torch.Size([3])

# %%
bg_image_path = 'green-military.png'
bg_image_path = 'cyan_back.png'
bg_image = Image.open(bg_image_path).convert('RGB')
# Display the background image
print("Let's display the background image")
bg_image.show()
bg_image = np.array(bg_image)

print(bg_image[50,50,:])
# Out:
# Let's display the background image
# <PIL.Image.Image image mode=RGB size=750x450>
# [  0 255 255]

# %%
# load an image
image_path = 'image_chat_background.png'
image = Image.open(image_path).convert('RGB')

# Display the image
print("Let's display the image")

image.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # load an image
#       2 image_path = 'image_chat_background.png'
# ----> 3 image = Image.open(image_path).convert('RGB')
#       5 # Display the image
#       6 print("Let's display the image")
#
# NameError: name 'Image' is not defined

# %%
from PIL import Image
import numpy as np

# Load the image
image_path = 'vero.jpg'  # Replace with the actual path to your image

bg_image = Image.open(image_path).convert('RGB')
bg_image = np.array(bg_image) 
# plot the image
import matplotlib.pyplot as plt
plt.imshow(bg_image)
plt.show()

# resize the image to 122 x 68 x 3
bg_image = Image.open(image_path).convert('RGB')
bg_image = bg_image.resize((122, 68))
bg_image = np.array(bg_image) 
print(bg_image.shape)

plt.imshow(bg_image)
plt.show()


# Shape is 450*750*3
# Resize it to 122 x 68 x 3
bg_image = Image.open(image_path).convert('RGB')

bg_image = bg_image[:122,:68,:]
plt.imshow(bg_image)
plt.show()
# Out:
# (68, 122, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 28
#      24 # Shape is 450*750*3
#      25 # Resize it to 122 x 68 x 3
#      26 bg_image = Image.open(image_path).convert('RGB')
# ---> 28 bg_image = bg_image[:122,:68,:]
#      29 plt.imshow(bg_image)
#      30 plt.show()
#
# TypeError: 'Image' object is not subscriptable

# %%
from PIL import Image
import numpy as np

# Load the image
image_path = 'orange-pastel.jpg'  # Replace with the actual path to your image

bg_image = Image.open(image_path).convert('RGB')
bg_image = np.array(bg_image) 
# plot the image
import matplotlib.pyplot as plt
plt.imshow(bg_image)
plt.show()

bg_image = bg_image[:68,:122,:]
plt.imshow(bg_image)
plt.show()

print(bg_image.shape)
print(bg_image[50,50,:])
# Out:
# (68, 122, 3)
# [254 115  20]

# %%
from PIL import Image
import numpy as np

# Load the image
image_path = 'green-military.png'  # Replace with the actual path to your image

bg_image = Image.open(image_path).convert('RGB')
bg_image = np.array(bg_image) 
# plot the image
import matplotlib.pyplot as plt
plt.imshow(bg_image)
plt.show()

# resize the image to 122 x 68 x 3
bg_image = Image.open(image_path).convert('RGB')
bg_image = bg_image.resize((68, 122))
bg_image = np.array(bg_image) 
print(bg_image.shape)

plt.imshow(bg_image)
plt.show()


# Shape is 450*750*3
# Resize it to 122 x 68 x 3
bg_image = Image.open(image_path).convert('RGB')

bg_image = bg_image[:122,:68,:]
plt.imshow(bg_image)
plt.show()
# Out:
# (68, 122, 3)

# %%
image_path = 'gt_image.png'
image = Image.open(image_path).convert('RGB')

# Display the image
print("Let's display the image")
image.show()

bg_image = np.array(image)
print(bg_image.shape)
# Out:
# Let's display the image
# <PIL.Image.Image image mode=RGB size=122x68>
# (68, 122, 3)

# %%
from PIL import Image
import numpy as np
import torch

# Load the image
image_path = 'carr.jpg'  # Replace with the actual path to your image

# Load background image
bg_image = Image.open(image_path).convert('RGB')
# bg_image = bg_image.resize((68, 122))

bg_image = np.array(bg_image) 
print(bg_image.shape)
bg_image = bg_image[:68,:,:]

# bg_image = bg_image.transpose(1, 0, 2)

# Shape is 450*750*3
# Resize it to 122 x 68 x 3

bg_image = torch.from_numpy(bg_image).float() / 255.0

print(bg_image.shape)

plt.imshow(bg_image)
# Out:
# (81, 122, 3)
# torch.Size([68, 122, 3])

# %%
import numpy as np
bg_image_path = bg_image_path
bg_image = Image.open(bg_image_path).convert('RGB')
bg_image = np.array(bg_image).astype(np.float32) / (255*255)
print(bg_image.shape)
print(bg_image[10,25,:])

# show the image
import matplotlib.pyplot as plt
plt.imshow(bg_image)
plt.show()
# Out:
# (450, 750, 3)
# [0.         0.00392157 0.00392157]

# %%
# display the image dimension
print("The dimension of the image is: ")
print(bg_image.size)
print(bg_image.format)
print(bg_image.mode)

print(bg_image.getpixel((0, 0)))
print(bg_image.getpixel((0, 1)))
# Out:
# The dimension of the image is:
# (750, 450)
# None
# RGB
# (0, 255, 255)
# (0, 255, 255)

# %%
from torchvision import transforms

transform = transforms.ToTensor()
bg_image = transform(bg_image).to("cuda")
print(bg_image.shape)
print(bg_image[0, 0, 0])
# Out:
# torch.Size([3, 1200, 1200])
# tensor(0.6118, device='cuda:0')

# %%
# convert bg_image in numpy array
bg_image = bg_image.cpu().numpy()
print(bg_image.shape)
# Out:
# (3, 1200, 1200)

# %%
print(bg_image[:,5,5])
# Out:
# [0.6117647  0.59607846 0.54901963]

# %%
// Retrieve the background color from the image
float bg_color[3];
// Normalize the pixel colors of bg_image between 0 and 1

for (int ch = 0; ch < CHANNELS; ch++)
{
    bg_color[ch] = bg_image[ch * H * W + pix_id] / 255.0f;
}
# Out:
#   Cell In[11], line 1
#     // Retrieve the background color from the image
#     ^
# SyntaxError: invalid syntax
